# %% [markdown]
# # Speech Recognition — Exploration
#
# Starter notebook untuk eksplorasi awal (COMP6822001).

# %%
import torchaudio
import librosa

print(torchaudio.__version__)
print(librosa.__version__)
