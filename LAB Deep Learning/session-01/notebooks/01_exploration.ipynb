# %% [markdown]
# # Deep Learning — Exploration
#
# Starter notebook untuk eksplorasi awal (COMP6826001).

# %%
import torch
import pandas as pd

print(torch.__version__)
print(torch.cuda.is_available())
